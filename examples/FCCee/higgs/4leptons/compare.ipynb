# %%
# Load coffeafccanalyses output
from coffea.util import load

from collections import defaultdict
from numbers import Number
import glob, re

# %%
def accumulate(dicts):
    """
    Recursively merges a list of dictionaries, supporting:
    - Numeric summation
    - List concatenation
    - Set union
    - Histogram addition (from `hist`)
    - Nested dictionaries
    - Key exceptions (preserve first)
    """
    try:
        from hist import Hist
    except ImportError:
        Hist = None  # Skip if hist is not available

    exception_list = {'Labels'}
    grouped = defaultdict(list)

    for d in dicts:
        for k, v in d.items():
            grouped[k].append(v)

    outdict = {}

    for key, values in grouped.items():
        first = values[0]

        if key in exception_list:
            outdict[key] = first
        elif all(isinstance(v, dict) for v in values):
            outdict[key] = accumulate(values)
        elif all(isinstance(v, list) for v in values):
            outdict[key] = sum(values, [])  # concatenate
        elif all(isinstance(v, set) for v in values):
            result = set()
            for v in values:
                result |= v
            outdict[key] = result
        elif Hist and all(isinstance(v, Hist) for v in values):
            total = values[0]
            for v in values[1:]:
                total += v
            outdict[key] = total
        elif all(isinstance(v, Number) for v in values):
            outdict[key] = sum(values)
        else:
            # Mixed types or strings — keep the first
            outdict[key] = first

    return outdict

# %%
#########################
# Load the coffea files #
#########################
#Input configuration

coffeafccanalyses_input_directory = "Batch"
output_filename = "4leptons"

input_path = coffeafccanalyses_input_directory+"/"
base_filename = output_filename+".coffea"
# print(f'Current configuration:\n\tinput_path:\t{input_path}\n\tbase_filename:\t{base_filename}\n')
# print("Loading coffea files...")

#Find coffea files
coffea_files = glob.glob(input_path+'*.coffea')
# print('Detected coffea files:')
for file in coffea_files : print('\t'+file)
# print(f'Choosing:\n\t{base_filename}')

#Find chunked coffea files and combine them
chunked_coffea_files = glob.glob(input_path+base_filename.strip('.coffea')+'-chunk*.coffea')
if len(chunked_coffea_files) != 0 :
    # print('Joining chunks:')
    chunk_index_list = []
    chunk_list = []
    for file in chunked_coffea_files:
        # print('\t'+file)
        chunk_list.append(file)
        chunk_index_list.append(int(re.search('-chunk(.*).coffea',file).group(1)))
    chunk_index_list.sort()

    #Check if there are missing chunks
    full_set = set(range(len(chunk_index_list)))
    lst_set = set(chunk_index_list)
    missing = list(full_set - lst_set)
    if len(missing) != 0:
        raise FileNotFoundError(f'Missing chunk indexes : {missing}')

    #Load and accumulate all the chunks
    input_list = [load(file) for file in chunk_list]
    coffeafcc_input = accumulate(input_list)

#If there is only one chunk no need to join chunks
else :
    coffeafcc_input = load(input_path+base_filename)
# Out:
# Current configuration:
# 	input_path:	Batch/
# 	base_filename:	4leptons.coffea
#
# Loading coffea files...
# Detected coffea files:
# 	Batch/4leptons-chunk0.coffea
# 	Batch/4leptons-chunk1.coffea
# 	Batch/4leptons-chunk10.coffea
# 	Batch/4leptons-chunk100.coffea
# 	Batch/4leptons-chunk101.coffea
# 	Batch/4leptons-chunk102.coffea
# 	Batch/4leptons-chunk103.coffea
# 	Batch/4leptons-chunk104.coffea
# 	Batch/4leptons-chunk105.coffea
# 	Batch/4leptons-chunk106.coffea
# 	Batch/4leptons-chunk107.coffea
# 	Batch/4leptons-chunk108.coffea
# 	Batch/4leptons-chunk109.coffea
# 	Batch/4leptons-chunk11.coffea
# 	Batch/4leptons-chunk110.coffea
# 	Batch/4leptons-chunk111.coffea
# 	Batch/4leptons-chunk112.coffea
# 	Batch/4leptons-chunk113.coffea
# 	Batch/4leptons-chunk114.coffea
# 	Batch/4leptons-chunk115.coffea
# 	Batch/4leptons-chunk116.coffea
# 	Batch/4leptons-chunk117.coffea
# 	Batch/4leptons-chunk118.coffea
# 	Batch/4leptons-chunk119.coffea
# 	Batch/4leptons-chunk12.coffea
# 	Batch/4leptons-chunk120.coffea
# 	Batch/4leptons-chunk121.coffea
# 	Batch/4leptons-chunk122.coffea
# 	Batch/4leptons-chunk123.coffea
# 	Batch/4leptons-chunk124.coffea
# 	Batch/4leptons-chunk125.coffea
# 	Batch/4leptons-chunk126.coffea
# 	Batch/4leptons-chunk127.coffea
# 	Batch/4leptons-chunk128.coffea
# 	Batch/4leptons-chunk129.coffea
# 	Batch/4leptons-chunk13.coffea
# 	Batch/4leptons-chunk130.coffea
# 	Batch/4leptons-chunk131.coffea
# 	Batch/4leptons-chunk132.coffea
# 	Batch/4leptons-chunk133.coffea
# 	Batch/4leptons-chunk134.coffea
# 	Batch/4leptons-chunk135.coffea
# 	Batch/4leptons-chunk136.coffea
# 	Batch/4leptons-chunk137.coffea
# 	Batch/4leptons-chunk138.coffea
# 	Batch/4leptons-chunk139.coffea
# 	Batch/4leptons-chunk14.coffea
# 	Batch/4leptons-chunk140.coffea
# 	Batch/4leptons-chunk141.coffea
# 	Batch/4leptons-chunk142.coffea
# 	Batch/4leptons-chunk143.coffea
# 	Batch/4leptons-chunk144.coffea
# 	Batch/4leptons-chunk145.coffea
# 	Batch/4leptons-chunk146.coffea
# 	Batch/4leptons-chunk147.coffea
# 	Batch/4leptons-chunk148.coffea
# 	Batch/4leptons-chunk149.coffea
# 	Batch/4leptons-chunk15.coffea
# 	Batch/4leptons-chunk150.coffea
# 	Batch/4leptons-chunk151.coffea
# 	Batch/4leptons-chunk152.coffea
# 	Batch/4leptons-chunk153.coffea
# 	Batch/4leptons-chunk154.coffea
# 	Batch/4leptons-chunk155.coffea
# 	Batch/4leptons-chunk156.coffea
# 	Batch/4leptons-chunk157.coffea
# 	Batch/4leptons-chunk158.coffea
# 	Batch/4leptons-chunk159.coffea
# 	Batch/4leptons-chunk16.coffea
# 	Batch/4leptons-chunk160.coffea
# 	Batch/4leptons-chunk161.coffea
# 	Batch/4leptons-chunk162.coffea
# 	Batch/4leptons-chunk163.coffea
# 	Batch/4leptons-chunk164.coffea
# 	Batch/4leptons-chunk165.coffea
# 	Batch/4leptons-chunk166.coffea
# 	Batch/4leptons-chunk167.coffea
# 	Batch/4leptons-chunk168.coffea
# 	Batch/4leptons-chunk169.coffea
# 	Batch/4leptons-chunk17.coffea
# 	Batch/4leptons-chunk170.coffea
# 	Batch/4leptons-chunk171.coffea
# 	Batch/4leptons-chunk172.coffea
# 	Batch/4leptons-chunk173.coffea
# 	Batch/4leptons-chunk174.coffea
# 	Batch/4leptons-chunk175.coffea
# 	Batch/4leptons-chunk176.coffea
# 	Batch/4leptons-chunk177.coffea
# 	Batch/4leptons-chunk178.coffea
# 	Batch/4leptons-chunk179.coffea
# 	Batch/4leptons-chunk18.coffea
# 	Batch/4leptons-chunk180.coffea
# 	Batch/4leptons-chunk181.coffea
# 	Batch/4leptons-chunk182.coffea
# 	Batch/4leptons-chunk183.coffea
# 	Batch/4leptons-chunk184.coffea
# 	Batch/4leptons-chunk185.coffea
# 	Batch/4leptons-chunk186.coffea
# 	Batch/4leptons-chunk187.coffea
# 	Batch/4leptons-chunk188.coffea
# 	Batch/4leptons-chunk189.coffea
# 	Batch/4leptons-chunk19.coffea
# 	Batch/4leptons-chunk190.coffea
# 	Batch/4leptons-chunk191.coffea
# 	Batch/4leptons-chunk192.coffea
# 	Batch/4leptons-chunk193.coffea
# 	Batch/4leptons-chunk194.coffea
# 	Batch/4leptons-chunk195.coffea
# 	Batch/4leptons-chunk196.coffea
# 	Batch/4leptons-chunk197.coffea
# 	Batch/4leptons-chunk198.coffea
# 	Batch/4leptons-chunk199.coffea
# 	Batch/4leptons-chunk2.coffea
# 	Batch/4leptons-chunk20.coffea
# 	Batch/4leptons-chunk200.coffea
# 	Batch/4leptons-chunk201.coffea
# 	Batch/4leptons-chunk202.coffea
# 	Batch/4leptons-chunk203.coffea
# 	Batch/4leptons-chunk204.coffea
# 	Batch/4leptons-chunk205.coffea
# 	Batch/4leptons-chunk206.coffea
# 	Batch/4leptons-chunk207.coffea
# 	Batch/4leptons-chunk208.coffea
# 	Batch/4leptons-chunk209.coffea
# 	Batch/4leptons-chunk21.coffea
# 	Batch/4leptons-chunk210.coffea
# 	Batch/4leptons-chunk211.coffea
# 	Batch/4leptons-chunk212.coffea
# 	Batch/4leptons-chunk213.coffea
# 	Batch/4leptons-chunk214.coffea
# 	Batch/4leptons-chunk215.coffea
# 	Batch/4leptons-chunk216.coffea
# 	Batch/4leptons-chunk217.coffea
# 	Batch/4leptons-chunk218.coffea
# 	Batch/4leptons-chunk219.coffea
# 	Batch/4leptons-chunk22.coffea
# 	Batch/4leptons-chunk220.coffea
# 	Batch/4leptons-chunk221.coffea
# 	Batch/4leptons-chunk222.coffea
# 	Batch/4leptons-chunk223.coffea
# 	Batch/4leptons-chunk224.coffea
# 	Batch/4leptons-chunk225.coffea
# 	Batch/4leptons-chunk226.coffea
# 	Batch/4leptons-chunk227.coffea
# 	Batch/4leptons-chunk228.coffea
# 	Batch/4leptons-chunk229.coffea
# 	Batch/4leptons-chunk23.coffea
# 	Batch/4leptons-chunk230.coffea
# 	Batch/4leptons-chunk231.coffea
# 	Batch/4leptons-chunk232.coffea
# 	Batch/4leptons-chunk233.coffea
# 	Batch/4leptons-chunk234.coffea
# 	Batch/4leptons-chunk235.coffea
# 	Batch/4leptons-chunk236.coffea
# 	Batch/4leptons-chunk237.coffea
# 	Batch/4leptons-chunk238.coffea
# 	Batch/4leptons-chunk239.coffea
# 	Batch/4leptons-chunk24.coffea
# 	Batch/4leptons-chunk240.coffea
# 	Batch/4leptons-chunk241.coffea
# 	Batch/4leptons-chunk242.coffea
# 	Batch/4leptons-chunk243.coffea
# 	Batch/4leptons-chunk244.coffea
# 	Batch/4leptons-chunk245.coffea
# 	Batch/4leptons-chunk246.coffea
# 	Batch/4leptons-chunk247.coffea
# 	Batch/4leptons-chunk248.coffea
# 	Batch/4leptons-chunk249.coffea
# 	Batch/4leptons-chunk25.coffea
# 	Batch/4leptons-chunk250.coffea
# 	Batch/4leptons-chunk251.coffea
# 	Batch/4leptons-chunk252.coffea
# 	Batch/4leptons-chunk253.coffea
# 	Batch/4leptons-chunk254.coffea
# 	Batch/4leptons-chunk255.coffea
# 	Batch/4leptons-chunk256.coffea
# 	Batch/4leptons-chunk257.coffea
# 	Batch/4leptons-chunk258.coffea
# 	Batch/4leptons-chunk259.coffea
# 	Batch/4leptons-chunk26.coffea
# 	Batch/4leptons-chunk260.coffea
# 	Batch/4leptons-chunk261.coffea
# 	Batch/4leptons-chunk262.coffea
# 	Batch/4leptons-chunk263.coffea
# 	Batch/4leptons-chunk264.coffea
# 	Batch/4leptons-chunk265.coffea
# 	Batch/4leptons-chunk266.coffea
# 	Batch/4leptons-chunk267.coffea
# 	Batch/4leptons-chunk268.coffea
# 	Batch/4leptons-chunk269.coffea
# 	Batch/4leptons-chunk27.coffea
# 	Batch/4leptons-chunk270.coffea
# 	Batch/4leptons-chunk271.coffea
# 	Batch/4leptons-chunk272.coffea
# 	Batch/4leptons-chunk273.coffea
# 	Batch/4leptons-chunk274.coffea
# 	Batch/4leptons-chunk275.coffea
# 	Batch/4leptons-chunk276.coffea
# 	Batch/4leptons-chunk277.coffea
# 	Batch/4leptons-chunk278.coffea
# 	Batch/4leptons-chunk279.coffea
# 	Batch/4leptons-chunk28.coffea
# 	Batch/4leptons-chunk280.coffea
# 	Batch/4leptons-chunk281.coffea
# 	Batch/4leptons-chunk282.coffea
# 	Batch/4leptons-chunk283.coffea
# 	Batch/4leptons-chunk284.coffea
# 	Batch/4leptons-chunk285.coffea
# 	Batch/4leptons-chunk286.coffea
# 	Batch/4leptons-chunk287.coffea
# 	Batch/4leptons-chunk288.coffea
# 	Batch/4leptons-chunk289.coffea
# 	Batch/4leptons-chunk29.coffea
# 	Batch/4leptons-chunk290.coffea
# 	Batch/4leptons-chunk291.coffea
# 	Batch/4leptons-chunk292.coffea
# 	Batch/4leptons-chunk293.coffea
# 	Batch/4leptons-chunk294.coffea
# 	Batch/4leptons-chunk295.coffea
# 	Batch/4leptons-chunk296.coffea
# 	Batch/4leptons-chunk297.coffea
# 	Batch/4leptons-chunk298.coffea
# 	Batch/4leptons-chunk299.coffea
# 	Batch/4leptons-chunk3.coffea
# 	Batch/4leptons-chunk30.coffea
# 	Batch/4leptons-chunk300.coffea
# 	Batch/4leptons-chunk301.coffea
# 	Batch/4leptons-chunk302.coffea
# 	Batch/4leptons-chunk303.coffea
# 	Batch/4leptons-chunk304.coffea
# 	Batch/4leptons-chunk305.coffea
# 	Batch/4leptons-chunk306.coffea
# 	Batch/4leptons-chunk307.coffea
# 	Batch/4leptons-chunk308.coffea
# 	Batch/4leptons-chunk309.coffea
# 	Batch/4leptons-chunk31.coffea
# 	Batch/4leptons-chunk310.coffea
# 	Batch/4leptons-chunk311.coffea
# 	Batch/4leptons-chunk312.coffea
# 	Batch/4leptons-chunk313.coffea
# 	Batch/4leptons-chunk314.coffea
# 	Batch/4leptons-chunk315.coffea
# 	Batch/4leptons-chunk316.coffea
# 	Batch/4leptons-chunk317.coffea
# 	Batch/4leptons-chunk318.coffea
# 	Batch/4leptons-chunk319.coffea
# 	Batch/4leptons-chunk32.coffea
# 	Batch/4leptons-chunk320.coffea
# 	Batch/4leptons-chunk321.coffea
# 	Batch/4leptons-chunk322.coffea
# 	Batch/4leptons-chunk323.coffea
# 	Batch/4leptons-chunk324.coffea
# 	Batch/4leptons-chunk325.coffea
# 	Batch/4leptons-chunk326.coffea
# 	Batch/4leptons-chunk327.coffea
# 	Batch/4leptons-chunk328.coffea
# 	Batch/4leptons-chunk329.coffea
# 	Batch/4leptons-chunk33.coffea
# 	Batch/4leptons-chunk330.coffea
# 	Batch/4leptons-chunk331.coffea
# 	Batch/4leptons-chunk332.coffea
# 	Batch/4leptons-chunk333.coffea
# 	Batch/4leptons-chunk334.coffea
# 	Batch/4leptons-chunk335.coffea
# 	Batch/4leptons-chunk336.coffea
# 	Batch/4leptons-chunk337.coffea
# 	Batch/4leptons-chunk338.coffea
# 	Batch/4leptons-chunk339.coffea
# 	Batch/4leptons-chunk34.coffea
# 	Batch/4leptons-chunk340.coffea
# 	Batch/4leptons-chunk341.coffea
# 	Batch/4leptons-chunk342.coffea
# 	Batch/4leptons-chunk343.coffea
# 	Batch/4leptons-chunk344.coffea
# 	Batch/4leptons-chunk345.coffea
# 	Batch/4leptons-chunk346.coffea
# 	Batch/4leptons-chunk347.coffea
# 	Batch/4leptons-chunk348.coffea
# 	Batch/4leptons-chunk349.coffea
# 	Batch/4leptons-chunk35.coffea
# 	Batch/4leptons-chunk350.coffea
# 	Batch/4leptons-chunk351.coffea
# 	Batch/4leptons-chunk352.coffea
# 	Batch/4leptons-chunk353.coffea
# 	Batch/4leptons-chunk354.coffea
# 	Batch/4leptons-chunk355.coffea
# 	Batch/4leptons-chunk356.coffea
# 	Batch/4leptons-chunk357.coffea
# 	Batch/4leptons-chunk358.coffea
# 	Batch/4leptons-chunk359.coffea
# 	Batch/4leptons-chunk36.coffea
# 	Batch/4leptons-chunk360.coffea
# 	Batch/4leptons-chunk361.coffea
# 	Batch/4leptons-chunk362.coffea
# 	Batch/4leptons-chunk363.coffea
# 	Batch/4leptons-chunk364.coffea
# 	Batch/4leptons-chunk365.coffea
# 	Batch/4leptons-chunk366.coffea
# 	Batch/4leptons-chunk367.coffea
# 	Batch/4leptons-chunk368.coffea
# 	Batch/4leptons-chunk369.coffea
# 	Batch/4leptons-chunk37.coffea
# 	Batch/4leptons-chunk370.coffea
# 	Batch/4leptons-chunk371.coffea
# 	Batch/4leptons-chunk372.coffea
# 	Batch/4leptons-chunk373.coffea
# 	Batch/4leptons-chunk374.coffea
# 	Batch/4leptons-chunk375.coffea
# 	Batch/4leptons-chunk376.coffea
# 	Batch/4leptons-chunk377.coffea
# 	Batch/4leptons-chunk378.coffea
# 	Batch/4leptons-chunk379.coffea
# 	Batch/4leptons-chunk38.coffea
# 	Batch/4leptons-chunk380.coffea
# 	Batch/4leptons-chunk381.coffea
# 	Batch/4leptons-chunk382.coffea
# 	Batch/4leptons-chunk383.coffea
# 	Batch/4leptons-chunk384.coffea
# 	Batch/4leptons-chunk385.coffea
# 	Batch/4leptons-chunk386.coffea
# 	Batch/4leptons-chunk387.coffea
# 	Batch/4leptons-chunk388.coffea
# 	Batch/4leptons-chunk389.coffea
# 	Batch/4leptons-chunk39.coffea
# 	Batch/4leptons-chunk390.coffea
# 	Batch/4leptons-chunk391.coffea
# 	Batch/4leptons-chunk392.coffea
# 	Batch/4leptons-chunk393.coffea
# 	Batch/4leptons-chunk394.coffea
# 	Batch/4leptons-chunk395.coffea
# 	Batch/4leptons-chunk396.coffea
# 	Batch/4leptons-chunk397.coffea
# 	Batch/4leptons-chunk398.coffea
# 	Batch/4leptons-chunk399.coffea
# 	Batch/4leptons-chunk4.coffea
# 	Batch/4leptons-chunk40.coffea
# 	Batch/4leptons-chunk400.coffea
# 	Batch/4leptons-chunk401.coffea
# 	Batch/4leptons-chunk402.coffea
# 	Batch/4leptons-chunk403.coffea
# 	Batch/4leptons-chunk404.coffea
# 	Batch/4leptons-chunk405.coffea
# 	Batch/4leptons-chunk406.coffea
# 	Batch/4leptons-chunk407.coffea
# 	Batch/4leptons-chunk408.coffea
# 	Batch/4leptons-chunk409.coffea
# 	Batch/4leptons-chunk41.coffea
# 	Batch/4leptons-chunk410.coffea
# 	Batch/4leptons-chunk411.coffea
# 	Batch/4leptons-chunk412.coffea
# 	Batch/4leptons-chunk413.coffea
# 	Batch/4leptons-chunk414.coffea
# 	Batch/4leptons-chunk415.coffea
# 	Batch/4leptons-chunk416.coffea
# 	Batch/4leptons-chunk417.coffea
# 	Batch/4leptons-chunk418.coffea
# 	Batch/4leptons-chunk419.coffea
# 	Batch/4leptons-chunk42.coffea
# 	Batch/4leptons-chunk420.coffea
# 	Batch/4leptons-chunk421.coffea
# 	Batch/4leptons-chunk422.coffea
# 	Batch/4leptons-chunk423.coffea
# 	Batch/4leptons-chunk424.coffea
# 	Batch/4leptons-chunk425.coffea
# 	Batch/4leptons-chunk426.coffea
# 	Batch/4leptons-chunk427.coffea
# 	Batch/4leptons-chunk428.coffea
# 	Batch/4leptons-chunk429.coffea
# 	Batch/4leptons-chunk43.coffea
# 	Batch/4leptons-chunk430.coffea
# 	Batch/4leptons-chunk431.coffea
# 	Batch/4leptons-chunk432.coffea
# 	Batch/4leptons-chunk433.coffea
# 	Batch/4leptons-chunk434.coffea
# 	Batch/4leptons-chunk435.coffea
# 	Batch/4leptons-chunk436.coffea
# 	Batch/4leptons-chunk437.coffea
# 	Batch/4leptons-chunk438.coffea
# 	Batch/4leptons-chunk439.coffea
# 	Batch/4leptons-chunk44.coffea
# 	Batch/4leptons-chunk440.coffea
# 	Batch/4leptons-chunk441.coffea
# 	Batch/4leptons-chunk442.coffea
# 	Batch/4leptons-chunk443.coffea
# 	Batch/4leptons-chunk444.coffea
# 	Batch/4leptons-chunk445.coffea
# 	Batch/4leptons-chunk446.coffea
# 	Batch/4leptons-chunk447.coffea
# 	Batch/4leptons-chunk448.coffea
# 	Batch/4leptons-chunk449.coffea
# 	Batch/4leptons-chunk45.coffea
# 	Batch/4leptons-chunk450.coffea
# 	Batch/4leptons-chunk451.coffea
# 	Batch/4leptons-chunk452.coffea
# 	Batch/4leptons-chunk453.coffea
# 	Batch/4leptons-chunk454.coffea
# 	Batch/4leptons-chunk455.coffea
# 	Batch/4leptons-chunk456.coffea
# 	Batch/4leptons-chunk457.coffea
# 	Batch/4leptons-chunk458.coffea
# 	Batch/4leptons-chunk459.coffea
# 	Batch/4leptons-chunk46.coffea
# 	Batch/4leptons-chunk460.coffea
# 	Batch/4leptons-chunk461.coffea
# 	Batch/4leptons-chunk462.coffea
# 	Batch/4leptons-chunk463.coffea
# 	Batch/4leptons-chunk464.coffea
# 	Batch/4leptons-chunk465.coffea
# 	Batch/4leptons-chunk466.coffea
# 	Batch/4leptons-chunk467.coffea
# 	Batch/4leptons-chunk468.coffea
# 	Batch/4leptons-chunk469.coffea
# 	Batch/4leptons-chunk47.coffea
# 	Batch/4leptons-chunk470.coffea
# 	Batch/4leptons-chunk471.coffea
# 	Batch/4leptons-chunk472.coffea
# 	Batch/4leptons-chunk473.coffea
# 	Batch/4leptons-chunk474.coffea
# 	Batch/4leptons-chunk475.coffea
# 	Batch/4leptons-chunk476.coffea
# 	Batch/4leptons-chunk477.coffea
# 	Batch/4leptons-chunk478.coffea
# 	Batch/4leptons-chunk479.coffea
# 	Batch/4leptons-chunk48.coffea
# 	Batch/4leptons-chunk480.coffea
# 	Batch/4leptons-chunk481.coffea
# 	Batch/4leptons-chunk482.coffea
# 	Batch/4leptons-chunk483.coffea
# 	Batch/4leptons-chunk484.coffea
# 	Batch/4leptons-chunk485.coffea
# 	Batch/4leptons-chunk486.coffea
# 	Batch/4leptons-chunk487.coffea
# 	Batch/4leptons-chunk488.coffea
# 	Batch/4leptons-chunk489.coffea
# 	Batch/4leptons-chunk49.coffea
# 	Batch/4leptons-chunk490.coffea
# 	Batch/4leptons-chunk491.coffea
# 	Batch/4leptons-chunk492.coffea
# 	Batch/4leptons-chunk493.coffea
# 	Batch/4leptons-chunk494.coffea
# 	Batch/4leptons-chunk495.coffea
# 	Batch/4leptons-chunk496.coffea
# 	Batch/4leptons-chunk497.coffea
# 	Batch/4leptons-chunk498.coffea
# 	Batch/4leptons-chunk499.coffea
# 	Batch/4leptons-chunk5.coffea
# 	Batch/4leptons-chunk50.coffea
# 	Batch/4leptons-chunk51.coffea
# 	Batch/4leptons-chunk52.coffea
# 	Batch/4leptons-chunk53.coffea
# 	Batch/4leptons-chunk54.coffea
# 	Batch/4leptons-chunk55.coffea
# 	Batch/4leptons-chunk56.coffea
# 	Batch/4leptons-chunk57.coffea
# 	Batch/4leptons-chunk58.coffea
# 	Batch/4leptons-chunk59.coffea
# 	Batch/4leptons-chunk6.coffea
# 	Batch/4leptons-chunk60.coffea
# 	Batch/4leptons-chunk61.coffea
# 	Batch/4leptons-chunk62.coffea
# 	Batch/4leptons-chunk63.coffea
# 	Batch/4leptons-chunk64.coffea
# 	Batch/4leptons-chunk65.coffea
# 	Batch/4leptons-chunk66.coffea
# 	Batch/4leptons-chunk67.coffea
# 	Batch/4leptons-chunk68.coffea
# 	Batch/4leptons-chunk69.coffea
# 	Batch/4leptons-chunk7.coffea
# 	Batch/4leptons-chunk70.coffea
# 	Batch/4leptons-chunk71.coffea
# 	Batch/4leptons-chunk72.coffea
# 	Batch/4leptons-chunk73.coffea
# 	Batch/4leptons-chunk74.coffea
# 	Batch/4leptons-chunk75.coffea
# 	Batch/4leptons-chunk76.coffea
# 	Batch/4leptons-chunk77.coffea
# 	Batch/4leptons-chunk78.coffea
# 	Batch/4leptons-chunk79.coffea
# 	Batch/4leptons-chunk8.coffea
# 	Batch/4leptons-chunk80.coffea
# 	Batch/4leptons-chunk81.coffea
# 	Batch/4leptons-chunk82.coffea
# 	Batch/4leptons-chunk83.coffea
# 	Batch/4leptons-chunk84.coffea
# 	Batch/4leptons-chunk85.coffea
# 	Batch/4leptons-chunk86.coffea
# 	Batch/4leptons-chunk87.coffea
# 	Batch/4leptons-chunk88.coffea
# 	Batch/4leptons-chunk89.coffea
# 	Batch/4leptons-chunk9.coffea
# 	Batch/4leptons-chunk90.coffea
# 	Batch/4leptons-chunk91.coffea
# 	Batch/4leptons-chunk92.coffea
# 	Batch/4leptons-chunk93.coffea
# 	Batch/4leptons-chunk94.coffea
# 	Batch/4leptons-chunk95.coffea
# 	Batch/4leptons-chunk96.coffea
# 	Batch/4leptons-chunk97.coffea
# 	Batch/4leptons-chunk98.coffea
# 	Batch/4leptons-chunk99.coffea
# Choosing:
# 	4leptons.coffea
# Joining chunks:
# 	Batch/4leptons-chunk0.coffea
# 	Batch/4leptons-chunk1.coffea
# 	Batch/4leptons-chunk10.coffea
# 	Batch/4leptons-chunk100.coffea
# 	Batch/4leptons-chunk101.coffea
# 	Batch/4leptons-chunk102.coffea
# 	Batch/4leptons-chunk103.coffea
# 	Batch/4leptons-chunk104.coffea
# 	Batch/4leptons-chunk105.coffea
# 	Batch/4leptons-chunk106.coffea
# 	Batch/4leptons-chunk107.coffea
# 	Batch/4leptons-chunk108.coffea
# 	Batch/4leptons-chunk109.coffea
# 	Batch/4leptons-chunk11.coffea
# 	Batch/4leptons-chunk110.coffea
# 	Batch/4leptons-chunk111.coffea
# 	Batch/4leptons-chunk112.coffea
# 	Batch/4leptons-chunk113.coffea
# 	Batch/4leptons-chunk114.coffea
# 	Batch/4leptons-chunk115.coffea
# 	Batch/4leptons-chunk116.coffea
# 	Batch/4leptons-chunk117.coffea
# 	Batch/4leptons-chunk118.coffea
# 	Batch/4leptons-chunk119.coffea
# 	Batch/4leptons-chunk12.coffea
# 	Batch/4leptons-chunk120.coffea
# 	Batch/4leptons-chunk121.coffea
# 	Batch/4leptons-chunk122.coffea
# 	Batch/4leptons-chunk123.coffea
# 	Batch/4leptons-chunk124.coffea
# 	Batch/4leptons-chunk125.coffea
# 	Batch/4leptons-chunk126.coffea
# 	Batch/4leptons-chunk127.coffea
# 	Batch/4leptons-chunk128.coffea
# 	Batch/4leptons-chunk129.coffea
# 	Batch/4leptons-chunk13.coffea
# 	Batch/4leptons-chunk130.coffea
# 	Batch/4leptons-chunk131.coffea
# 	Batch/4leptons-chunk132.coffea
# 	Batch/4leptons-chunk133.coffea
# 	Batch/4leptons-chunk134.coffea
# 	Batch/4leptons-chunk135.coffea
# 	Batch/4leptons-chunk136.coffea
# 	Batch/4leptons-chunk137.coffea
# 	Batch/4leptons-chunk138.coffea
# 	Batch/4leptons-chunk139.coffea
# 	Batch/4leptons-chunk14.coffea
# 	Batch/4leptons-chunk140.coffea
# 	Batch/4leptons-chunk141.coffea
# 	Batch/4leptons-chunk142.coffea
# 	Batch/4leptons-chunk143.coffea
# 	Batch/4leptons-chunk144.coffea
# 	Batch/4leptons-chunk145.coffea
# 	Batch/4leptons-chunk146.coffea
# 	Batch/4leptons-chunk147.coffea
# 	Batch/4leptons-chunk148.coffea
# 	Batch/4leptons-chunk149.coffea
# 	Batch/4leptons-chunk15.coffea
# 	Batch/4leptons-chunk150.coffea
# 	Batch/4leptons-chunk151.coffea
# 	Batch/4leptons-chunk152.coffea
# 	Batch/4leptons-chunk153.coffea
# 	Batch/4leptons-chunk154.coffea
# 	Batch/4leptons-chunk155.coffea
# 	Batch/4leptons-chunk156.coffea
# 	Batch/4leptons-chunk157.coffea
# 	Batch/4leptons-chunk158.coffea
# 	Batch/4leptons-chunk159.coffea
# 	Batch/4leptons-chunk16.coffea
# 	Batch/4leptons-chunk160.coffea
# 	Batch/4leptons-chunk161.coffea
# 	Batch/4leptons-chunk162.coffea
# 	Batch/4leptons-chunk163.coffea
# 	Batch/4leptons-chunk164.coffea
# 	Batch/4leptons-chunk165.coffea
# 	Batch/4leptons-chunk166.coffea
# 	Batch/4leptons-chunk167.coffea
# 	Batch/4leptons-chunk168.coffea
# 	Batch/4leptons-chunk169.coffea
# 	Batch/4leptons-chunk17.coffea
# 	Batch/4leptons-chunk170.coffea
# 	Batch/4leptons-chunk171.coffea
# 	Batch/4leptons-chunk172.coffea
# 	Batch/4leptons-chunk173.coffea
# 	Batch/4leptons-chunk174.coffea
# 	Batch/4leptons-chunk175.coffea
# 	Batch/4leptons-chunk176.coffea
# 	Batch/4leptons-chunk177.coffea
# 	Batch/4leptons-chunk178.coffea
# 	Batch/4leptons-chunk179.coffea
# 	Batch/4leptons-chunk18.coffea
# 	Batch/4leptons-chunk180.coffea
# 	Batch/4leptons-chunk181.coffea
# 	Batch/4leptons-chunk182.coffea
# 	Batch/4leptons-chunk183.coffea
# 	Batch/4leptons-chunk184.coffea
# 	Batch/4leptons-chunk185.coffea
# 	Batch/4leptons-chunk186.coffea
# 	Batch/4leptons-chunk187.coffea
# 	Batch/4leptons-chunk188.coffea
# 	Batch/4leptons-chunk189.coffea
# 	Batch/4leptons-chunk19.coffea
# 	Batch/4leptons-chunk190.coffea
# 	Batch/4leptons-chunk191.coffea
# 	Batch/4leptons-chunk192.coffea
# 	Batch/4leptons-chunk193.coffea
# 	Batch/4leptons-chunk194.coffea
# 	Batch/4leptons-chunk195.coffea
# 	Batch/4leptons-chunk196.coffea
# 	Batch/4leptons-chunk197.coffea
# 	Batch/4leptons-chunk198.coffea
# 	Batch/4leptons-chunk199.coffea
# 	Batch/4leptons-chunk2.coffea
# 	Batch/4leptons-chunk20.coffea
# 	Batch/4leptons-chunk200.coffea
# 	Batch/4leptons-chunk201.coffea
# 	Batch/4leptons-chunk202.coffea
# 	Batch/4leptons-chunk203.coffea
# 	Batch/4leptons-chunk204.coffea
# 	Batch/4leptons-chunk205.coffea
# 	Batch/4leptons-chunk206.coffea
# 	Batch/4leptons-chunk207.coffea
# 	Batch/4leptons-chunk208.coffea
# 	Batch/4leptons-chunk209.coffea
# 	Batch/4leptons-chunk21.coffea
# 	Batch/4leptons-chunk210.coffea
# 	Batch/4leptons-chunk211.coffea
# 	Batch/4leptons-chunk212.coffea
# 	Batch/4leptons-chunk213.coffea
# 	Batch/4leptons-chunk214.coffea
# 	Batch/4leptons-chunk215.coffea
# 	Batch/4leptons-chunk216.coffea
# 	Batch/4leptons-chunk217.coffea
# 	Batch/4leptons-chunk218.coffea
# 	Batch/4leptons-chunk219.coffea
# 	Batch/4leptons-chunk22.coffea
# 	Batch/4leptons-chunk220.coffea
# 	Batch/4leptons-chunk221.coffea
# 	Batch/4leptons-chunk222.coffea
# 	Batch/4leptons-chunk223.coffea
# 	Batch/4leptons-chunk224.coffea
# 	Batch/4leptons-chunk225.coffea
# 	Batch/4leptons-chunk226.coffea
# 	Batch/4leptons-chunk227.coffea
# 	Batch/4leptons-chunk228.coffea
# 	Batch/4leptons-chunk229.coffea
# 	Batch/4leptons-chunk23.coffea
# 	Batch/4leptons-chunk230.coffea
# 	Batch/4leptons-chunk231.coffea
# 	Batch/4leptons-chunk232.coffea
# 	Batch/4leptons-chunk233.coffea
# 	Batch/4leptons-chunk234.coffea
# 	Batch/4leptons-chunk235.coffea
# 	Batch/4leptons-chunk236.coffea
# 	Batch/4leptons-chunk237.coffea
# 	Batch/4leptons-chunk238.coffea
# 	Batch/4leptons-chunk239.coffea
# 	Batch/4leptons-chunk24.coffea
# 	Batch/4leptons-chunk240.coffea
# 	Batch/4leptons-chunk241.coffea
# 	Batch/4leptons-chunk242.coffea
# 	Batch/4leptons-chunk243.coffea
# 	Batch/4leptons-chunk244.coffea
# 	Batch/4leptons-chunk245.coffea
# 	Batch/4leptons-chunk246.coffea
# 	Batch/4leptons-chunk247.coffea
# 	Batch/4leptons-chunk248.coffea
# 	Batch/4leptons-chunk249.coffea
# 	Batch/4leptons-chunk25.coffea
# 	Batch/4leptons-chunk250.coffea
# 	Batch/4leptons-chunk251.coffea
# 	Batch/4leptons-chunk252.coffea
# 	Batch/4leptons-chunk253.coffea
# 	Batch/4leptons-chunk254.coffea
# 	Batch/4leptons-chunk255.coffea
# 	Batch/4leptons-chunk256.coffea
# 	Batch/4leptons-chunk257.coffea
# 	Batch/4leptons-chunk258.coffea
# 	Batch/4leptons-chunk259.coffea
# 	Batch/4leptons-chunk26.coffea
# 	Batch/4leptons-chunk260.coffea
# 	Batch/4leptons-chunk261.coffea
# 	Batch/4leptons-chunk262.coffea
# 	Batch/4leptons-chunk263.coffea
# 	Batch/4leptons-chunk264.coffea
# 	Batch/4leptons-chunk265.coffea
# 	Batch/4leptons-chunk266.coffea
# 	Batch/4leptons-chunk267.coffea
# 	Batch/4leptons-chunk268.coffea
# 	Batch/4leptons-chunk269.coffea
# 	Batch/4leptons-chunk27.coffea
# 	Batch/4leptons-chunk270.coffea
# 	Batch/4leptons-chunk271.coffea
# 	Batch/4leptons-chunk272.coffea
# 	Batch/4leptons-chunk273.coffea
# 	Batch/4leptons-chunk274.coffea
# 	Batch/4leptons-chunk275.coffea
# 	Batch/4leptons-chunk276.coffea
# 	Batch/4leptons-chunk277.coffea
# 	Batch/4leptons-chunk278.coffea
# 	Batch/4leptons-chunk279.coffea
# 	Batch/4leptons-chunk28.coffea
# 	Batch/4leptons-chunk280.coffea
# 	Batch/4leptons-chunk281.coffea
# 	Batch/4leptons-chunk282.coffea
# 	Batch/4leptons-chunk283.coffea
# 	Batch/4leptons-chunk284.coffea
# 	Batch/4leptons-chunk285.coffea
# 	Batch/4leptons-chunk286.coffea
# 	Batch/4leptons-chunk287.coffea
# 	Batch/4leptons-chunk288.coffea
# 	Batch/4leptons-chunk289.coffea
# 	Batch/4leptons-chunk29.coffea
# 	Batch/4leptons-chunk290.coffea
# 	Batch/4leptons-chunk291.coffea
# 	Batch/4leptons-chunk292.coffea
# 	Batch/4leptons-chunk293.coffea
# 	Batch/4leptons-chunk294.coffea
# 	Batch/4leptons-chunk295.coffea
# 	Batch/4leptons-chunk296.coffea
# 	Batch/4leptons-chunk297.coffea
# 	Batch/4leptons-chunk298.coffea
# 	Batch/4leptons-chunk299.coffea
# 	Batch/4leptons-chunk3.coffea
# 	Batch/4leptons-chunk30.coffea
# 	Batch/4leptons-chunk300.coffea
# 	Batch/4leptons-chunk301.coffea
# 	Batch/4leptons-chunk302.coffea
# 	Batch/4leptons-chunk303.coffea
# 	Batch/4leptons-chunk304.coffea
# 	Batch/4leptons-chunk305.coffea
# 	Batch/4leptons-chunk306.coffea
# 	Batch/4leptons-chunk307.coffea
# 	Batch/4leptons-chunk308.coffea
# 	Batch/4leptons-chunk309.coffea
# 	Batch/4leptons-chunk31.coffea
# 	Batch/4leptons-chunk310.coffea
# 	Batch/4leptons-chunk311.coffea
# 	Batch/4leptons-chunk312.coffea
# 	Batch/4leptons-chunk313.coffea
# 	Batch/4leptons-chunk314.coffea
# 	Batch/4leptons-chunk315.coffea
# 	Batch/4leptons-chunk316.coffea
# 	Batch/4leptons-chunk317.coffea
# 	Batch/4leptons-chunk318.coffea
# 	Batch/4leptons-chunk319.coffea
# 	Batch/4leptons-chunk32.coffea
# 	Batch/4leptons-chunk320.coffea
# 	Batch/4leptons-chunk321.coffea
# 	Batch/4leptons-chunk322.coffea
# 	Batch/4leptons-chunk323.coffea
# 	Batch/4leptons-chunk324.coffea
# 	Batch/4leptons-chunk325.coffea
# 	Batch/4leptons-chunk326.coffea
# 	Batch/4leptons-chunk327.coffea
# 	Batch/4leptons-chunk328.coffea
# 	Batch/4leptons-chunk329.coffea
# 	Batch/4leptons-chunk33.coffea
# 	Batch/4leptons-chunk330.coffea
# 	Batch/4leptons-chunk331.coffea
# 	Batch/4leptons-chunk332.coffea
# 	Batch/4leptons-chunk333.coffea
# 	Batch/4leptons-chunk334.coffea
# 	Batch/4leptons-chunk335.coffea
# 	Batch/4leptons-chunk336.coffea
# 	Batch/4leptons-chunk337.coffea
# 	Batch/4leptons-chunk338.coffea
# 	Batch/4leptons-chunk339.coffea
# 	Batch/4leptons-chunk34.coffea
# 	Batch/4leptons-chunk340.coffea
# 	Batch/4leptons-chunk341.coffea
# 	Batch/4leptons-chunk342.coffea
# 	Batch/4leptons-chunk343.coffea
# 	Batch/4leptons-chunk344.coffea
# 	Batch/4leptons-chunk345.coffea
# 	Batch/4leptons-chunk346.coffea
# 	Batch/4leptons-chunk347.coffea
# 	Batch/4leptons-chunk348.coffea
# 	Batch/4leptons-chunk349.coffea
# 	Batch/4leptons-chunk35.coffea
# 	Batch/4leptons-chunk350.coffea
# 	Batch/4leptons-chunk351.coffea
# 	Batch/4leptons-chunk352.coffea
# 	Batch/4leptons-chunk353.coffea
# 	Batch/4leptons-chunk354.coffea
# 	Batch/4leptons-chunk355.coffea
# 	Batch/4leptons-chunk356.coffea
# 	Batch/4leptons-chunk357.coffea
# 	Batch/4leptons-chunk358.coffea
# 	Batch/4leptons-chunk359.coffea
# 	Batch/4leptons-chunk36.coffea
# 	Batch/4leptons-chunk360.coffea
# 	Batch/4leptons-chunk361.coffea
# 	Batch/4leptons-chunk362.coffea
# 	Batch/4leptons-chunk363.coffea
# 	Batch/4leptons-chunk364.coffea
# 	Batch/4leptons-chunk365.coffea
# 	Batch/4leptons-chunk366.coffea
# 	Batch/4leptons-chunk367.coffea
# 	Batch/4leptons-chunk368.coffea
# 	Batch/4leptons-chunk369.coffea
# 	Batch/4leptons-chunk37.coffea
# 	Batch/4leptons-chunk370.coffea
# 	Batch/4leptons-chunk371.coffea
# 	Batch/4leptons-chunk372.coffea
# 	Batch/4leptons-chunk373.coffea
# 	Batch/4leptons-chunk374.coffea
# 	Batch/4leptons-chunk375.coffea
# 	Batch/4leptons-chunk376.coffea
# 	Batch/4leptons-chunk377.coffea
# 	Batch/4leptons-chunk378.coffea
# 	Batch/4leptons-chunk379.coffea
# 	Batch/4leptons-chunk38.coffea
# 	Batch/4leptons-chunk380.coffea
# 	Batch/4leptons-chunk381.coffea
# 	Batch/4leptons-chunk382.coffea
# 	Batch/4leptons-chunk383.coffea
# 	Batch/4leptons-chunk384.coffea
# 	Batch/4leptons-chunk385.coffea
# 	Batch/4leptons-chunk386.coffea
# 	Batch/4leptons-chunk387.coffea
# 	Batch/4leptons-chunk388.coffea
# 	Batch/4leptons-chunk389.coffea
# 	Batch/4leptons-chunk39.coffea
# 	Batch/4leptons-chunk390.coffea
# 	Batch/4leptons-chunk391.coffea
# 	Batch/4leptons-chunk392.coffea
# 	Batch/4leptons-chunk393.coffea
# 	Batch/4leptons-chunk394.coffea
# 	Batch/4leptons-chunk395.coffea
# 	Batch/4leptons-chunk396.coffea
# 	Batch/4leptons-chunk397.coffea
# 	Batch/4leptons-chunk398.coffea
# 	Batch/4leptons-chunk399.coffea
# 	Batch/4leptons-chunk4.coffea
# 	Batch/4leptons-chunk40.coffea
# 	Batch/4leptons-chunk400.coffea
# 	Batch/4leptons-chunk401.coffea
# 	Batch/4leptons-chunk402.coffea
# 	Batch/4leptons-chunk403.coffea
# 	Batch/4leptons-chunk404.coffea
# 	Batch/4leptons-chunk405.coffea
# 	Batch/4leptons-chunk406.coffea
# 	Batch/4leptons-chunk407.coffea
# 	Batch/4leptons-chunk408.coffea
# 	Batch/4leptons-chunk409.coffea
# 	Batch/4leptons-chunk41.coffea
# 	Batch/4leptons-chunk410.coffea
# 	Batch/4leptons-chunk411.coffea
# 	Batch/4leptons-chunk412.coffea
# 	Batch/4leptons-chunk413.coffea
# 	Batch/4leptons-chunk414.coffea
# 	Batch/4leptons-chunk415.coffea
# 	Batch/4leptons-chunk416.coffea
# 	Batch/4leptons-chunk417.coffea
# 	Batch/4leptons-chunk418.coffea
# 	Batch/4leptons-chunk419.coffea
# 	Batch/4leptons-chunk42.coffea
# 	Batch/4leptons-chunk420.coffea
# 	Batch/4leptons-chunk421.coffea
# 	Batch/4leptons-chunk422.coffea
# 	Batch/4leptons-chunk423.coffea
# 	Batch/4leptons-chunk424.coffea
# 	Batch/4leptons-chunk425.coffea
# 	Batch/4leptons-chunk426.coffea
# 	Batch/4leptons-chunk427.coffea
# 	Batch/4leptons-chunk428.coffea
# 	Batch/4leptons-chunk429.coffea
# 	Batch/4leptons-chunk43.coffea
# 	Batch/4leptons-chunk430.coffea
# 	Batch/4leptons-chunk431.coffea
# 	Batch/4leptons-chunk432.coffea
# 	Batch/4leptons-chunk433.coffea
# 	Batch/4leptons-chunk434.coffea
# 	Batch/4leptons-chunk435.coffea
# 	Batch/4leptons-chunk436.coffea
# 	Batch/4leptons-chunk437.coffea
# 	Batch/4leptons-chunk438.coffea
# 	Batch/4leptons-chunk439.coffea
# 	Batch/4leptons-chunk44.coffea
# 	Batch/4leptons-chunk440.coffea
# 	Batch/4leptons-chunk441.coffea
# 	Batch/4leptons-chunk442.coffea
# 	Batch/4leptons-chunk443.coffea
# 	Batch/4leptons-chunk444.coffea
# 	Batch/4leptons-chunk445.coffea
# 	Batch/4leptons-chunk446.coffea
# 	Batch/4leptons-chunk447.coffea
# 	Batch/4leptons-chunk448.coffea
# 	Batch/4leptons-chunk449.coffea
# 	Batch/4leptons-chunk45.coffea
# 	Batch/4leptons-chunk450.coffea
# 	Batch/4leptons-chunk451.coffea
# 	Batch/4leptons-chunk452.coffea
# 	Batch/4leptons-chunk453.coffea
# 	Batch/4leptons-chunk454.coffea
# 	Batch/4leptons-chunk455.coffea
# 	Batch/4leptons-chunk456.coffea
# 	Batch/4leptons-chunk457.coffea
# 	Batch/4leptons-chunk458.coffea
# 	Batch/4leptons-chunk459.coffea
# 	Batch/4leptons-chunk46.coffea
# 	Batch/4leptons-chunk460.coffea
# 	Batch/4leptons-chunk461.coffea
# 	Batch/4leptons-chunk462.coffea
# 	Batch/4leptons-chunk463.coffea
# 	Batch/4leptons-chunk464.coffea
# 	Batch/4leptons-chunk465.coffea
# 	Batch/4leptons-chunk466.coffea
# 	Batch/4leptons-chunk467.coffea
# 	Batch/4leptons-chunk468.coffea
# 	Batch/4leptons-chunk469.coffea
# 	Batch/4leptons-chunk47.coffea
# 	Batch/4leptons-chunk470.coffea
# 	Batch/4leptons-chunk471.coffea
# 	Batch/4leptons-chunk472.coffea
# 	Batch/4leptons-chunk473.coffea
# 	Batch/4leptons-chunk474.coffea
# 	Batch/4leptons-chunk475.coffea
# 	Batch/4leptons-chunk476.coffea
# 	Batch/4leptons-chunk477.coffea
# 	Batch/4leptons-chunk478.coffea
# 	Batch/4leptons-chunk479.coffea
# 	Batch/4leptons-chunk48.coffea
# 	Batch/4leptons-chunk480.coffea
# 	Batch/4leptons-chunk481.coffea
# 	Batch/4leptons-chunk482.coffea
# 	Batch/4leptons-chunk483.coffea
# 	Batch/4leptons-chunk484.coffea
# 	Batch/4leptons-chunk485.coffea
# 	Batch/4leptons-chunk486.coffea
# 	Batch/4leptons-chunk487.coffea
# 	Batch/4leptons-chunk488.coffea
# 	Batch/4leptons-chunk489.coffea
# 	Batch/4leptons-chunk49.coffea
# 	Batch/4leptons-chunk490.coffea
# 	Batch/4leptons-chunk491.coffea
# 	Batch/4leptons-chunk492.coffea
# 	Batch/4leptons-chunk493.coffea
# 	Batch/4leptons-chunk494.coffea
# 	Batch/4leptons-chunk495.coffea
# 	Batch/4leptons-chunk496.coffea
# 	Batch/4leptons-chunk497.coffea
# 	Batch/4leptons-chunk498.coffea
# 	Batch/4leptons-chunk499.coffea
# 	Batch/4leptons-chunk5.coffea
# 	Batch/4leptons-chunk50.coffea
# 	Batch/4leptons-chunk51.coffea
# 	Batch/4leptons-chunk52.coffea
# 	Batch/4leptons-chunk53.coffea
# 	Batch/4leptons-chunk54.coffea
# 	Batch/4leptons-chunk55.coffea
# 	Batch/4leptons-chunk56.coffea
# 	Batch/4leptons-chunk57.coffea
# 	Batch/4leptons-chunk58.coffea
# 	Batch/4leptons-chunk59.coffea
# 	Batch/4leptons-chunk6.coffea
# 	Batch/4leptons-chunk60.coffea
# 	Batch/4leptons-chunk61.coffea
# 	Batch/4leptons-chunk62.coffea
# 	Batch/4leptons-chunk63.coffea
# 	Batch/4leptons-chunk64.coffea
# 	Batch/4leptons-chunk65.coffea
# 	Batch/4leptons-chunk66.coffea
# 	Batch/4leptons-chunk67.coffea
# 	Batch/4leptons-chunk68.coffea
# 	Batch/4leptons-chunk69.coffea
# 	Batch/4leptons-chunk7.coffea
# 	Batch/4leptons-chunk70.coffea
# 	Batch/4leptons-chunk71.coffea
# 	Batch/4leptons-chunk72.coffea
# 	Batch/4leptons-chunk73.coffea
# 	Batch/4leptons-chunk74.coffea
# 	Batch/4leptons-chunk75.coffea
# 	Batch/4leptons-chunk76.coffea
# 	Batch/4leptons-chunk77.coffea
# 	Batch/4leptons-chunk78.coffea
# 	Batch/4leptons-chunk79.coffea
# 	Batch/4leptons-chunk8.coffea
# 	Batch/4leptons-chunk80.coffea
# 	Batch/4leptons-chunk81.coffea
# 	Batch/4leptons-chunk82.coffea
# 	Batch/4leptons-chunk83.coffea
# 	Batch/4leptons-chunk84.coffea
# 	Batch/4leptons-chunk85.coffea
# 	Batch/4leptons-chunk86.coffea
# 	Batch/4leptons-chunk87.coffea
# 	Batch/4leptons-chunk88.coffea
# 	Batch/4leptons-chunk89.coffea
# 	Batch/4leptons-chunk9.coffea
# 	Batch/4leptons-chunk90.coffea
# 	Batch/4leptons-chunk91.coffea
# 	Batch/4leptons-chunk92.coffea
# 	Batch/4leptons-chunk93.coffea
# 	Batch/4leptons-chunk94.coffea
# 	Batch/4leptons-chunk95.coffea
# 	Batch/4leptons-chunk96.coffea
# 	Batch/4leptons-chunk97.coffea
# 	Batch/4leptons-chunk98.coffea
# 	Batch/4leptons-chunk99.coffea

# %%
coffeafcc_input['wzp6_ee_qqH_HZZ_llll_ecm240']
# Out:
# {'histograms': {'sel0': {'selectedmuons_p': Hist(Regular(250, 0, 250, label='Axis 0'), storage=Double()) # Sum: 568251.0,
#    'fourmuons_mass': Hist(Regular(50, 0, 250, label='Axis 0'), storage=Double()) # Sum: 134893.0,
#    'fourmuons_pmin': Hist(Regular(20, 0, 100, label='Axis 0'), storage=Double()) # Sum: 134893.0,
#    'Z_res_mass': Hist(Regular(50, 0, 250, label='Axis 0'), storage=Double()) # Sum: 138853.0,
#    'Z_non_res_mass': Hist(Regular(50, 0, 250, label='Axis 0'), storage=Double()) # Sum: 134893.0,
#    'vis_e_woMuons': Hist(Regular(50, 0, 250, label='Axis 0'), storage=Double()) # Sum: 134893.0,
#    'iso_least_isolated_muon': Hist(Regular(50, 0, 20, label='Axis 0'), storage=Double()) # Sum: 134575.0 (134893.0 with flow),
#    'missing_p': Hist(Regular(50, 0, 250, label='Axis 0'), storage=Double()) # Sum: 105764.0 (134893.0 with flow),
#    'cos_theta_miss': Hist(Regular(100, 0, 1, label='Axis 0'), storage=Double()) # Sum: 44331.0 (134893.0 with flow)},
#   'sel1': {'selectedmuons_p': Hist(Regular(250, 0, 250, label='Axis 0'), storage=Double()) # Sum: 568251.0,
#    'fourmuons_mass': Hist(Regular(50, 0, 250, label='Axis 0'), storage=Double()) # Sum: 134893.0,
#    'fourmuons_pmin': Hist(Regular(20, 0, 100, label='Axis 0'), storage=Double()) # Sum: 134893.0,
#    'Z_res_mass': Hist(Regular(50, 0, 250, label='Axis 0'), storage=Double()) # Sum: 138853.0,
#    'Z_non_res_mass': Hist(Regular(50, 0, 250, label='Axis 0'), storage=Double()) # Sum: 134893.0,
#    'vis_e_woMuons': Hist(Regular(50, 0, 250, label='Axis 0'), storage=Double()) # Sum: 134893.0,
#    'iso_least_isolated_muon': Hist(Regular(50, 0, 20, label='Axis 0'), storage=Double()) # Sum: 134575.0 (134893.0 with flow),
#    'missing_p': Hist(Regular(50, 0, 250, label='Axis 0'), storage=Double()) # Sum: 105764.0 (134893.0 with flow),
#    'cos_theta_miss': Hist(Regular(100, 0, 1, label='Axis 0'), storage=Double()) # Sum: 44331.0 (134893.0 with flow)},
#   'sel2': {'selectedmuons_p': Hist(Regular(250, 0, 250, label='Axis 0'), storage=Double()) # Sum: 568251.0,
#    'fourmuons_mass': Hist(Regular(50, 0, 250, label='Axis 0'), storage=Double()) # Sum: 134893.0,
#    'fourmuons_pmin': Hist(Regular(20, 0, 100, label='Axis 0'), storage=Double()) # Sum: 134893.0,
#    'Z_res_mass': Hist(Regular(50, 0, 250, label='Axis 0'), storage=Double()) # Sum: 138853.0,
#    'Z_non_res_mass': Hist(Regular(50, 0, 250, label='Axis 0'), storage=Double()) # Sum: 134893.0,
#    'vis_e_woMuons': Hist(Regular(50, 0, 250, label='Axis 0'), storage=Double()) # Sum: 134893.0,
#    'iso_least_isolated_muon': Hist(Regular(50, 0, 20, label='Axis 0'), storage=Double()) # Sum: 134575.0 (134893.0 with flow),
#    'missing_p': Hist(Regular(50, 0, 250, label='Axis 0'), storage=Double()) # Sum: 105764.0 (134893.0 with flow),
#    'cos_theta_miss': Hist(Regular(100, 0, 1, label='Axis 0'), storage=Double()) # Sum: 44331.0 (134893.0 with flow)},
#   'sel3': {'selectedmuons_p': Hist(Regular(250, 0, 250, label='Axis 0'), storage=Double()) # Sum: 568251.0,
#    'fourmuons_mass': Hist(Regular(50, 0, 250, label='Axis 0'), storage=Double()) # Sum: 134893.0,
#    'fourmuons_pmin': Hist(Regular(20, 0, 100, label='Axis 0'), storage=Double()) # Sum: 134893.0,
#    'Z_res_mass': Hist(Regular(50, 0, 250, label='Axis 0'), storage=Double()) # Sum: 138853.0,
#    'Z_non_res_mass': Hist(Regular(50, 0, 250, label='Axis 0'), storage=Double()) # Sum: 134893.0,
#    'vis_e_woMuons': Hist(Regular(50, 0, 250, label='Axis 0'), storage=Double()) # Sum: 134893.0,
#    'iso_least_isolated_muon': Hist(Regular(50, 0, 20, label='Axis 0'), storage=Double()) # Sum: 134575.0 (134893.0 with flow),
#    'missing_p': Hist(Regular(50, 0, 250, label='Axis 0'), storage=Double()) # Sum: 105764.0 (134893.0 with flow),
#    'cos_theta_miss': Hist(Regular(100, 0, 1, label='Axis 0'), storage=Double()) # Sum: 44331.0 (134893.0 with flow)},
#   'sel4': {'selectedmuons_p': Hist(Regular(250, 0, 250, label='Axis 0'), storage=Double()) # Sum: 568251.0,
#    'fourmuons_mass': Hist(Regular(50, 0, 250, label='Axis 0'), storage=Double()) # Sum: 134893.0,
#    'fourmuons_pmin': Hist(Regular(20, 0, 100, label='Axis 0'), storage=Double()) # Sum: 134893.0,
#    'Z_res_mass': Hist(Regular(50, 0, 250, label='Axis 0'), storage=Double()) # Sum: 138853.0,
#    'Z_non_res_mass': Hist(Regular(50, 0, 250, label='Axis 0'), storage=Double()) # Sum: 134893.0,
#    'vis_e_woMuons': Hist(Regular(50, 0, 250, label='Axis 0'), storage=Double()) # Sum: 134893.0,
#    'iso_least_isolated_muon': Hist(Regular(50, 0, 20, label='Axis 0'), storage=Double()) # Sum: 134575.0 (134893.0 with flow),
#    'missing_p': Hist(Regular(50, 0, 250, label='Axis 0'), storage=Double()) # Sum: 105764.0 (134893.0 with flow),
#    'cos_theta_miss': Hist(Regular(100, 0, 1, label='Axis 0'), storage=Double()) # Sum: 44331.0 (134893.0 with flow)},
#   'sel5': {'selectedmuons_p': Hist(Regular(250, 0, 250, label='Axis 0'), storage=Double()) # Sum: 568251.0,
#    'fourmuons_mass': Hist(Regular(50, 0, 250, label='Axis 0'), storage=Double()) # Sum: 134893.0,
#    'fourmuons_pmin': Hist(Regular(20, 0, 100, label='Axis 0'), storage=Double()) # Sum: 134893.0,
#    'Z_res_mass': Hist(Regular(50, 0, 250, label='Axis 0'), storage=Double()) # Sum: 138853.0,
#    'Z_non_res_mass': Hist(Regular(50, 0, 250, label='Axis 0'), storage=Double()) # Sum: 134893.0,
#    'vis_e_woMuons': Hist(Regular(50, 0, 250, label='Axis 0'), storage=Double()) # Sum: 134893.0,
#    'iso_least_isolated_muon': Hist(Regular(50, 0, 20, label='Axis 0'), storage=Double()) # Sum: 134575.0 (134893.0 with flow),
#    'missing_p': Hist(Regular(50, 0, 250, label='Axis 0'), storage=Double()) # Sum: 105764.0 (134893.0 with flow),
#    'cos_theta_miss': Hist(Regular(100, 0, 1, label='Axis 0'), storage=Double()) # Sum: 44331.0 (134893.0 with flow)},
#   'sel6': {'selectedmuons_p': Hist(Regular(250, 0, 250, label='Axis 0'), storage=Double()) # Sum: 568251.0,
#    'fourmuons_mass': Hist(Regular(50, 0, 250, label='Axis 0'), storage=Double()) # Sum: 134893.0,
#    'fourmuons_pmin': Hist(Regular(20, 0, 100, label='Axis 0'), storage=Double()) # Sum: 134893.0,
#    'Z_res_mass': Hist(Regular(50, 0, 250, label='Axis 0'), storage=Double()) # Sum: 138853.0,
#    'Z_non_res_mass': Hist(Regular(50, 0, 250, label='Axis 0'), storage=Double()) # Sum: 134893.0,
#    'vis_e_woMuons': Hist(Regular(50, 0, 250, label='Axis 0'), storage=Double()) # Sum: 134893.0,
#    'iso_least_isolated_muon': Hist(Regular(50, 0, 20, label='Axis 0'), storage=Double()) # Sum: 134575.0 (134893.0 with flow),
#    'missing_p': Hist(Regular(50, 0, 250, label='Axis 0'), storage=Double()) # Sum: 105764.0 (134893.0 with flow),
#    'cos_theta_miss': Hist(Regular(100, 0, 1, label='Axis 0'), storage=Double()) # Sum: 44331.0 (134893.0 with flow)}},
#  'cutflow': {'sel0': {'Onecut': Hist(Integer(0, 2, name='onecut'), storage=Double()) # Sum: 2400000.0,
#    'Cutflow': Hist(Integer(0, 2, name='cutflow'), storage=Double()) # Sum: 2400000.0,
#    'Labels': ['initial', 'No cut']},
#   'sel1': {'Onecut': Hist(Integer(0, 3, name='onecut'), storage=Double()) # Sum: 3600000.0,
#    'Cutflow': Hist(Integer(0, 3, name='cutflow'), storage=Double()) # Sum: 3600000.0,
#    'Labels': ['initial', 'No cut', 'cut1']},
#   'sel2': {'Onecut': Hist(Integer(0, 4, name='onecut'), storage=Double()) # Sum: 4800000.0,
#    'Cutflow': Hist(Integer(0, 4, name='cutflow'), storage=Double()) # Sum: 4800000.0,
#    'Labels': ['initial', 'No cut', 'cut1', 'cut2']},
#   'sel3': {'Onecut': Hist(Integer(0, 5, name='onecut'), storage=Double()) # Sum: 6000000.0,
#    'Cutflow': Hist(Integer(0, 5, name='cutflow'), storage=Double()) # Sum: 6000000.0,
#    'Labels': ['initial', 'No cut', 'cut1', 'cut2', 'cut3']},
#   'sel4': {'Onecut': Hist(Integer(0, 6, name='onecut'), storage=Double()) # Sum: 7200000.0,
#    'Cutflow': Hist(Integer(0, 6, name='cutflow'), storage=Double()) # Sum: 7200000.0,
#    'Labels': ['initial', 'No cut', 'cut1', 'cut2', 'cut3', 'cut4']},
#   'sel5': {'Onecut': Hist(Integer(0, 7, name='onecut'), storage=Double()) # Sum: 8400000.0,
#    'Cutflow': Hist(Integer(0, 7, name='cutflow'), storage=Double()) # Sum: 8400000.0,
#    'Labels': ['initial', 'No cut', 'cut1', 'cut2', 'cut3', 'cut4', 'cut5']},
#   'sel6': {'Onecut': Hist(Integer(0, 8, name='onecut'), storage=Double()) # Sum: 9600000.0,
#    'Cutflow': Hist(Integer(0, 8, name='cutflow'), storage=Double()) # Sum: 9600000.0,
#    'Labels': ['initial',
#     'No cut',
#     'cut1',
#     'cut2',
#     'cut3',
#     'cut4',
#     'cut5',
#     'cut6']}}}

# %%
# Load FCCAnalyses output\
import uproot

# %%
# fcc_base_directory = "FCCAnalyses_output"
fcc_base_directory = "with_filter"
datasets = glob.glob(fcc_base_directory+"/*")

# %%
FCC_output = {}
for path in datasets:
    dataset_name = path.split('/')[-1]
    with uproot.open(path+"/chunk0.root") as f:
        FCC_output[dataset_name] = f['events'].arrays()

# %%
FCC_output['p8_ee_ZZ_ecm240'].fields
# Out:
# ['selected_muons_n',
#  'selected_muons_p',
#  'rest_of_muons.type',
#  'rest_of_muons.energy',
#  'rest_of_muons.momentum.x',
#  'rest_of_muons.momentum.y',
#  'rest_of_muons.momentum.z',
#  'rest_of_muons.referencePoint.x',
#  'rest_of_muons.referencePoint.y',
#  'rest_of_muons.referencePoint.z',
#  'rest_of_muons.charge',
#  'rest_of_muons.mass',
#  'rest_of_muons.goodnessOfPID',
#  'rest_of_muons.covMatrix[10]',
#  'rest_of_muons.clusters_begin',
#  'rest_of_muons.clusters_end',
#  'rest_of_muons.tracks_begin',
#  'rest_of_muons.tracks_end',
#  'rest_of_muons.particles_begin',
#  'rest_of_muons.particles_end',
#  'rest_of_muons.particleIDs_begin',
#  'rest_of_muons.particleIDs_end',
#  'fourMuons_p',
#  'fourMuons_mass',
#  'zll_mass',
#  'non_res_Z.type',
#  'non_res_Z.energy',
#  'non_res_Z.momentum.x',
#  'non_res_Z.momentum.y',
#  'non_res_Z.momentum.z',
#  'non_res_Z.referencePoint.x',
#  'non_res_Z.referencePoint.y',
#  'non_res_Z.referencePoint.z',
#  'non_res_Z.charge',
#  'non_res_Z.mass',
#  'non_res_Z.goodnessOfPID',
#  'non_res_Z.covMatrix[10]',
#  'non_res_Z.clusters_begin',
#  'non_res_Z.clusters_end',
#  'non_res_Z.tracks_begin',
#  'non_res_Z.tracks_end',
#  'non_res_Z.particles_begin',
#  'non_res_Z.particles_end',
#  'non_res_Z.particleIDs_begin',
#  'non_res_Z.particleIDs_end',
#  'non_res_Z_tlv',
#  'non_res_Z_m',
#  'vis_e_other_particles',
#  'fourMuons_pmin',
#  'non_res_Z_angle',
#  'fourMuons_iso',
#  'fourMuons_min_iso',
#  'pmiss',
#  'cosTheta_miss']

# %%
plots = {
    'selectedmuons_p':{'name':'selected_muons_p','title':'$\\mu_p$ [GeV]','xlabel':'$p_T$ [GeV]','ylabel':'Events','bins':250,'xmin':0,'xmax':250},

    'fourmuons_mass':{'name':'fourMuons_mass','title':'$M_{4\\mu}$ [GeV]','xlabel':'$Mass$ [GeV]','ylabel':'Events','bins':50,'xmin':0,'xmax':250},
    'fourmuons_pmin':{'name':'fourMuons_pmin','title':'$(P_{4\\mu})_{min}$ [GeV]','xlabel':'$p_{min}$ [GeV]','ylabel':'Events','bins':20,'xmin':0,'xmax':100},

    'Z_res_mass':{'name':'zll_mass','title':'On-shell $M_{\\mu\\mu}$ [GeV]','xlabel':'$Mass$ [GeV]','ylabel':'Events','bins':50,'xmin':0,'xmax':250},
    'Z_non_res_mass':{'name':'non_res_Z_m','title':'Off-shell $M_{\\mu\\mu}$ [GeV]','xlabel':'$Mass$ [GeV]','ylabel':'Events','bins':50,'xmin':0,'xmax':250},

    'vis_e_woMuons':{'name':'vis_e_other_particles','title':'Visible Energy excluding muons [GeV]','xlabel':'$E$ [GeV]','ylabel':'Events','bins':50,'xmin':0,'xmax':250},
    'iso_least_isolated_muon':{'name':'fourMuons_min_iso','title':'iso(least isolated muon)','xlabel':'iso','ylabel':'Events','bins':50,'xmin':0,'xmax':20},
    'missing_p':{'name':'pmiss','title':'missing p [GeV]','xlabel':'$p^{miss}$ [GeV]','ylabel':'Events','bins':50,'xmin':0,'xmax':250},
    'cos_theta_miss':{'name':'cosTheta_miss','title':'Cos(Theta_miss)','xlabel':'$cos_{miss}\\theta$','ylabel':'Events','bins':100,'xmin':0,'xmax':1},

}

# %%
histoList = {
    "selectedmuons_p":"selected_muons_p",
    "fourmuons_mass":"fourMuons_mass",
    "fourmuons_pmin":"fourMuons_pmin",
    "Z_res_mass":"zll_mass",
    "Z_non_res_mass":"non_res_Z_m",
    "vis_e_woMuons":"vis_e_other_particles",
    "iso_least_isolated_muon":"fourMuons_min_iso",
    "missing_p":"pmiss",
    "cos_theta_miss":"cosTheta_miss",
}

# %%
import hist
import awkward as ak

# %%
fcc_hists = {}
for dataset in FCC_output.keys():
    fcc_hists[dataset] = {}
    for name, var in histoList.items():
        to_plot = FCC_output[dataset][var]
        info = plots[name]
        fcc_hists[dataset][name] = hist.Hist.new.Reg( info['bins'], info['xmin'], info['xmax'] ).Double().fill(ak.ravel(to_plot))

# %%
fcc_hists['p8_ee_ZZ_ecm240']
# Out:
# {'selectedmuons_p': Hist(Regular(250, 0, 250, label='Axis 0'), storage=Double()) # Sum: 853.0,
#  'fourmuons_mass': Hist(Regular(50, 0, 250, label='Axis 0'), storage=Double()) # Sum: 213.0,
#  'fourmuons_pmin': Hist(Regular(20, 0, 100, label='Axis 0'), storage=Double()) # Sum: 213.0,
#  'Z_res_mass': Hist(Regular(50, 0, 250, label='Axis 0'), storage=Double()) # Sum: 213.0,
#  'Z_non_res_mass': Hist(Regular(50, 0, 250, label='Axis 0'), storage=Double()) # Sum: 213.0,
#  'vis_e_woMuons': Hist(Regular(50, 0, 250, label='Axis 0'), storage=Double()) # Sum: 213.0,
#  'iso_least_isolated_muon': Hist(Regular(50, 0, 20, label='Axis 0'), storage=Double()) # Sum: 209.0 (213.0 with flow),
#  'missing_p': Hist(Regular(50, 0, 250, label='Axis 0'), storage=Double()) # Sum: 155.0 (213.0 with flow),
#  'cos_theta_miss': Hist(Regular(100, 0, 1, label='Axis 0'), storage=Double()) # Sum: 213.0}

# %%
coffea_hists = {}
for dataset in coffeafcc_input.keys():
    coffea_hists[dataset] = {}
    for r_plots in histoList.keys():
        coffea_hists[dataset][r_plots] = coffeafcc_input[dataset]['histograms']['sel0'][r_plots]

# %%
coffea_hists['p8_ee_ZZ_ecm240']
# Out:
# {'selectedmuons_p': Hist(Regular(250, 0, 250, label='Axis 0'), storage=Double()) # Sum: 576920.0,
#  'fourmuons_mass': Hist(Regular(50, 0, 250, label='Axis 0'), storage=Double()) # Sum: 134025.0,
#  'fourmuons_pmin': Hist(Regular(20, 0, 100, label='Axis 0'), storage=Double()) # Sum: 134025.0,
#  'Z_res_mass': Hist(Regular(50, 0, 250, label='Axis 0'), storage=Double()) # Sum: 143641.0,
#  'Z_non_res_mass': Hist(Regular(50, 0, 250, label='Axis 0'), storage=Double()) # Sum: 134025.0,
#  'vis_e_woMuons': Hist(Regular(50, 0, 250, label='Axis 0'), storage=Double()) # Sum: 134025.0,
#  'iso_least_isolated_muon': Hist(Regular(50, 0, 20, label='Axis 0'), storage=Double()) # Sum: 132260.0 (134025.0 with flow),
#  'missing_p': Hist(Regular(50, 0, 250, label='Axis 0'), storage=Double()) # Sum: 98623.0 (134025.0 with flow),
#  'cos_theta_miss': Hist(Regular(100, 0, 1, label='Axis 0'), storage=Double()) # Sum: 48644.0 (134025.0 with flow)}

# %%
# Now we can finally compare the histograms from fcc_hists and coffea_hists

# %%
for dataset in fcc_hists.keys():
    print(f"Checking {dataset} ...")
    for name in fcc_hists[dataset].keys():
        print(f"\t{name}")
        diff = coffea_hists[dataset][name] - fcc_hists[dataset][name]
        print(f"\t\tDifference is {diff.sum()}")
# Out:
# Checking p8_ee_ZZ_ecm240 ...
# 	selectedmuons_p
# 		Difference is 576067.0
# 	fourmuons_mass
# 		Difference is 133812.0
# 	fourmuons_pmin
# 		Difference is 133812.0
# 	Z_res_mass
# 		Difference is 143428.0
# 	Z_non_res_mass
# 		Difference is 133812.0
# 	vis_e_woMuons
# 		Difference is 133812.0
# 	iso_least_isolated_muon
# 		Difference is 132051.0
# 	missing_p
# 		Difference is 98468.0
# 	cos_theta_miss
# 		Difference is 48431.0
